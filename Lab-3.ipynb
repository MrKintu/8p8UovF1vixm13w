# %% [markdown]
# 1) Import Libraries

# %%
import pandas as pd
import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %% [markdown]
# 2) Load Data

# %%
data = pd.read_csv("train.csv")
data
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %%
df = data[['text', 'target']]
df['text'] = df['text'].str.lower()

df
# Out:
# C:\Users\d-kin\AppData\Local\Temp\ipykernel_25652\1695621088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].str.lower()
#                                                    text  target
# 0     our deeds are the reason of this #earthquake m...       1
# 1                forest fire near la ronge sask. canada       1
# 2     all residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     just got sent this photo from ruby #alaska as ...       1
# ...                                                 ...     ...
# 7608  two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @thetawniest the out of control w...       1
# 7610  m1.94 [01:04 utc]?5km s of volcano hawaii. htt...       1
# 7611  police investigating after an e-bike collided ...       1
# 7612  the latest: more homes razed by northern calif...       1
#
# [7613 rows x 2 columns]

# %% [markdown]
# 3) Clean Data

# %%
url = "https://www.somesite.com This is othe text."

pattern = re.compile(r'https?://\S*')
pattern.findall(url)
# Out:
# ['https://www.somesite.com']

# %%
pattern.sub("$$$", url)
# Out:
# '$$$ This is othe text.'

# %%
df['text'] = df['text'].apply(lambda x: pattern.sub("", x))
df.head(50)
# Out:
# C:\Users\d-kin\AppData\Local\Temp\ipykernel_25652\3698504754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].apply(lambda x: pattern.sub("", x))
#                                                  text  target
# 0   our deeds are the reason of this #earthquake m...       1
# 1              forest fire near la ronge sask. canada       1
# 2   all residents asked to 'shelter in place' are ...       1
# 3   13,000 people receive #wildfires evacuation or...       1
# 4   just got sent this photo from ruby #alaska as ...       1
# 5   #rockyfire update => california hwy. 20 closed...       1
# 6   #flood #disaster heavy rain causes flash flood...       1
# 7   i'm on top of the hill and i can see a fire in...       1
# 8   there's an emergency evacuation happening now ...       1
# 9   i'm afraid that the tornado is coming to our a...       1
# 10        three people died from the heat wave so far       1
# 11  haha south tampa is getting flooded hah- wait ...       1
# 12  #raining #flooding #florida #tampabay #tampa 1...       1
# 13            #flood in bago myanmar #we arrived bago       1
# 14  damage to school bus on 80 in multi car crash ...       1
# 15                                     what's up man?       0
# 16                                      i love fruits       0
# 17                                   summer is lovely       0
# 18                                  my car is so fast       0
# 19                       what a goooooooaaaaaal!!!!!!       0
# 20                             this is ridiculous....       0
# 21                                  london is cool ;)       0
# 22                                        love skiing       0
# 23                              what a wonderful day!       0
# 24                                           looooool       0
# 25                     no way...i can't eat that shit       0
# 26                              was in nyc last week!       0
# 27                                 love my girlfriend       0
# 28                                          cooool :)       0
# 29                                 do you like pasta?       0
# 30                                           the end!       0
# 31                  @bbcmtd wholesale markets ablaze        1
# 32      we always try to bring the heavy. #metal #rt        0
# 33  #africanbaze: breaking news:nigeria flag set a...       1
# 34                 crying out for more! set me ablaze       0
# 35  on plus side look at the sky last night it was...       0
# 36  @phdsquares #mufc they've built so much hype a...       0
# 37                  inec office in abia set ablaze -        1
# 38  barbados #bridgetown jamaica ûò two cars set ...       1
# 39                             ablaze for you lord :d       0
# 40                         check these out:     #nsfw       0
# 41  on the outside you're ablaze and alive\r\nbut ...       0
# 42  had an awesome time visiting the cfc head offi...       0
# 43       soooo pumped for ablaze ???? @southridgelife       0
# 44  i wanted to set chicago ablaze with my preachi...       0
# 45  i gained 3 followers in the last week. you? kn...       0
# 46  how the west was burned: thousands of wildfire...       1
# 47  building the perfect tracklist to life leave t...       0
# 48                         check these out:     #nsfw       0
# 49  first night with retainers in. it's quite weir...       0

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
text = "Hello $# world ?% find *() this <>"
pattern2 = re.compile(r'[^\w\s]')
pattern2.findall(text)
# Out:
# ['$', '#', '?', '%', '*', '(', ')', '<', '>']

# %%
df['text'] = df['text'].apply(lambda x: pattern2.sub("", x))
df.head(50)
# Out:
# C:\Users\d-kin\AppData\Local\Temp\ipykernel_25652\754453846.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].apply(lambda x: pattern2.sub("", x))
#                                                  text  target
# 0   our deeds are the reason of this earthquake ma...       1
# 1               forest fire near la ronge sask canada       1
# 2   all residents asked to shelter in place are be...       1
# 3   13000 people receive wildfires evacuation orde...       1
# 4   just got sent this photo from ruby alaska as s...       1
# 5   rockyfire update  california hwy 20 closed in ...       1
# 6   flood disaster heavy rain causes flash floodin...       1
# 7   im on top of the hill and i can see a fire in ...       1
# 8   theres an emergency evacuation happening now i...       1
# 9    im afraid that the tornado is coming to our area       1
# 10        three people died from the heat wave so far       1
# 11  haha south tampa is getting flooded hah wait a...       1
# 12  raining flooding florida tampabay tampa 18 or ...       1
# 13              flood in bago myanmar we arrived bago       1
# 14  damage to school bus on 80 in multi car crash ...       1
# 15                                       whats up man       0
# 16                                      i love fruits       0
# 17                                   summer is lovely       0
# 18                                  my car is so fast       0
# 19                             what a goooooooaaaaaal       0
# 20                                 this is ridiculous       0
# 21                                    london is cool        0
# 22                                        love skiing       0
# 23                               what a wonderful day       0
# 24                                           looooool       0
# 25                         no wayi cant eat that shit       0
# 26                               was in nyc last week       0
# 27                                 love my girlfriend       0
# 28                                            cooool        0
# 29                                  do you like pasta       0
# 30                                            the end       0
# 31                   bbcmtd wholesale markets ablaze        1
# 32         we always try to bring the heavy metal rt        0
# 33  africanbaze breaking newsnigeria flag set abla...       1
# 34                  crying out for more set me ablaze       0
# 35  on plus side look at the sky last night it was...       0
# 36  phdsquares mufc theyve built so much hype arou...       0
# 37                   inec office in abia set ablaze         1
# 38  barbados bridgetown jamaica ûò two cars set ab...       1
# 39                              ablaze for you lord d       0
# 40                           check these out     nsfw       0
# 41  on the outside youre ablaze and alive\r\nbut y...       0
# 42  had an awesome time visiting the cfc head offi...       0
# 43            soooo pumped for ablaze  southridgelife       0
# 44  i wanted to set chicago ablaze with my preachi...       0
# 45  i gained 3 followers in the last week you know...       0
# 46  how the west was burned thousands of wildfires...       1
# 47  building the perfect tracklist to life leave t...       0
# 48                           check these out     nsfw       0
# 49  first night with retainers in its quite weird ...       0

# %% [markdown]
# 4) Stemming of the vocabulary

# %%
[_ for _ in text.split()]
# Out:
# ['Hello', '$#', 'world', '?%', 'find', '*()', 'this', '<>']

# %%
df['text'] = df['text'].apply(lambda x: [_ for _ in x.split()])
df['text'].head(20)
# Out:
# C:\Users\d-kin\AppData\Local\Temp\ipykernel_25652\2964385030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].apply(lambda x: [_ for _ in x.split()])
# 0     [our, deeds, are, the, reason, of, this, earth...
# 1         [forest, fire, near, la, ronge, sask, canada]
# 2     [all, residents, asked, to, shelter, in, place...
# 3     [13000, people, receive, wildfires, evacuation...
# 4     [just, got, sent, this, photo, from, ruby, ala...
# 5     [rockyfire, update, california, hwy, 20, close...
# 6     [flood, disaster, heavy, rain, causes, flash, ...
# 7     [im, on, top, of, the, hill, and, i, can, see,...
# 8     [theres, an, emergency, evacuation, happening,...
# 9     [im, afraid, that, the, tornado, is, coming, t...
# 10    [three, people, died, from, the, heat, wave, s...
# 11    [haha, south, tampa, is, getting, flooded, hah...
# 12    [raining, flooding, florida, tampabay, tampa, ...
# 13        [flood, in, bago, myanmar, we, arrived, bago]
# 14    [damage, to, school, bus, on, 80, in, multi, c...
# 15                                     [whats, up, man]
# 16                                    [i, love, fruits]
# 17                                 [summer, is, lovely]
# 18                              [my, car, is, so, fast]
# 19                           [what, a, goooooooaaaaaal]
# Name: text, dtype: object

# %%
# nltk.download('stopwords')
eng_stop = stopwords.words('English')
eng_stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
[_ for _ in text.split() if _ not in eng_stop]
# Out:
# ['Hello', '$#', 'world', '?%', 'find', '*()', '<>']

# %%
df['text'] = df['text'].apply(lambda x: [_ for _ in x if _ not in eng_stop])
df['text'].head(20)
# Out:
# C:\Users\d-kin\AppData\Local\Temp\ipykernel_25652\3909481511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].apply(lambda x: [_ for _ in x if _ not in eng_stop])
# 0     [deeds, reason, earthquake, may, allah, forgiv...
# 1         [forest, fire, near, la, ronge, sask, canada]
# 2     [residents, asked, shelter, place, notified, o...
# 3     [13000, people, receive, wildfires, evacuation...
# 4     [got, sent, photo, ruby, alaska, smoke, wildfi...
# 5     [rockyfire, update, california, hwy, 20, close...
# 6     [flood, disaster, heavy, rain, causes, flash, ...
# 7                     [im, top, hill, see, fire, woods]
# 8     [theres, emergency, evacuation, happening, bui...
# 9                   [im, afraid, tornado, coming, area]
# 10               [three, people, died, heat, wave, far]
# 11    [haha, south, tampa, getting, flooded, hah, wa...
# 12    [raining, flooding, florida, tampabay, tampa, ...
# 13                [flood, bago, myanmar, arrived, bago]
# 14    [damage, school, bus, 80, multi, car, crash, b...
# 15                                         [whats, man]
# 16                                       [love, fruits]
# 17                                     [summer, lovely]
# 18                                          [car, fast]
# 19                                    [goooooooaaaaaal]
# Name: text, dtype: object

# %%
st = PorterStemmer()

# %%
st.stem("running")
# Out:
# 'run'

# %%
[st.stem(_) for _ in text.split()]
# Out:
# ['hello', '$#', 'world', '?%', 'find', '*()', 'thi', '<>']

# %%
df['text'] = df['text'].apply(lambda x: [st.stem(_) for _ in x])
df['text'].head(20)
# Out:
# C:\Users\d-kin\AppData\Local\Temp\ipykernel_25652\1317486952.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].apply(lambda x: [st.stem(_) for _ in x])
# 0     [deed, reason, earthquak, may, allah, forgiv, us]
# 1          [forest, fire, near, la, rong, sask, canada]
# 2     [resid, ask, shelter, place, notifi, offic, ev...
# 3     [13000, peopl, receiv, wildfir, evacu, order, ...
# 4     [got, sent, photo, rubi, alaska, smoke, wildfi...
# 5     [rockyfir, updat, california, hwi, 20, close, ...
# 6     [flood, disast, heavi, rain, caus, flash, floo...
# 7                      [im, top, hill, see, fire, wood]
# 8     [there, emerg, evacu, happen, build, across, s...
# 9                     [im, afraid, tornado, come, area]
# 10                 [three, peopl, die, heat, wave, far]
# 11    [haha, south, tampa, get, flood, hah, wait, se...
# 12    [rain, flood, florida, tampabay, tampa, 18, 19...
# 13                  [flood, bago, myanmar, arriv, bago]
# 14    [damag, school, bu, 80, multi, car, crash, break]
# 15                                          [what, man]
# 16                                        [love, fruit]
# 17                                       [summer, love]
# 18                                          [car, fast]
# 19                                    [goooooooaaaaaal]
# Name: text, dtype: object

# %% [markdown]
# 5) Create Vocabulary Dictionary

# %%
dictionary = []
for rows in df['text']:
    for word in rows:
        dictionary.append(word)

dictionary = list(set(dictionary))
dictionary
# Out:
# ['goblu',
#  'high',
#  'pope',
#  'mug',
#  'morevoic',
#  'whirlwind',
#  'parter',
#  'small',
#  'deadgirltalk',
#  'woe',
#  'kasiakosek',
#  'poconorecord',
#  'nypd',
#  'mogacola',
#  'feelslikefob',
#  'contrast',
#  'nathan',
#  'ju',
#  'unsaf',
#  'first',
#  'baseman',
#  'rabbit',
#  'everybodi',
#  'ward',
#  'michaelwestbiz',
#  'counselor',
#  'honeybunzgem',
#  'pic',
#  'p45perez',
#  'sfgiant',
#  'b5',
#  'stonewal',
#  'slimebeast',
#  'ådaniel',
#  'afghetcleft',
#  'ironmanå',
#  'extermin',
#  'manag',
#  'motogp',
#  'robsimss',
#  'quiz',
#  'jeannamibian',
#  'gold',
#  'grudg',
#  'inj',
#  '900',
#  'loughe',
#  'strait',
#  'segment',
#  'topic',
#  'ir',
#  'pixelcanuck',
#  'steamship',
#  'djicemoon',
#  'demolish',
#  'hairbut',
#  'juic',
#  'end',
#  'badirand',
#  'peal',
#  'blais',
#  'akilah',
#  'behindashield',
#  'sl',
#  'reid',
#  'nitishkumar',
#  'blitz',
#  'bloopandablast',
#  'kcrw',
#  'windmi',
#  'imsort',
#  'basket',
#  'sarah',
#  'biggangvh1',
#  'retir',
#  'rise',
#  '1rockstar62',
#  'gray',
#  'downgrad',
#  'udhampuragain',
#  'litani',
#  'societi',
#  'push2left',
#  'philippi',
#  'va',
#  'hypo',
#  'fahlowcw',
#  'û_',
#  'rescuer',
#  '7475',
#  'mississippi',
#  'aintsheperti',
#  'wn',
#  'slaughter',
#  'aussi',
#  'hunterston',
#  'exhibit',
#  'resoluteshield',
#  'olliebailey11',
#  '7',
#  'damidnight',
#  'outnumb',
#  'fjord',
#  'idp',
#  'hanna_brooksi',
#  'offer',
#  'blowjob',
#  '60',
#  'social',
#  '23km',
#  'presum',
#  'ethic',
#  'exhaust',
#  'testicl',
#  'saku_uchiha_',
#  'milita',
#  'vampir',
#  'certainli',
#  'mind_mischief',
#  'scheme',
#  'punkblunt',
#  '9058778591',
#  'disasterû',
#  'concentr',
#  'bomairing',
#  'zomatoau',
#  'bonhomme37',
#  'lolol',
#  'icemoon',
#  'compet',
#  'cheer',
#  'function',
#  'akito',
#  'terrain',
#  'modibo',
#  'steel',
#  'sanûªa',
#  'thetimepast',
#  'hair',
#  'browseråêhijack',
#  'ûgood',
#  'waterû_',
#  'chiasson',
#  'special',
#  'pay',
#  'wce',
#  'jj',
#  'mediterranean',
#  'boundari',
#  'reddish',
#  'interrog',
#  'doppler',
#  'cat',
#  'littledeath',
#  'workd',
#  '_onlyftf',
#  'vela',
#  'pagasa',
#  'knive',
#  'ggindependencmessag',
#  'dravet',
#  'pd',
#  'sfgate',
#  'disgust',
#  'fundrais',
#  'legisl',
#  'constel',
#  '1030pm',
#  'oral',
#  'print',
#  'friend59',
#  'spin',
#  'faulti',
#  'refugio',
#  'mauryn143',
#  'storen',
#  'shell',
#  'poison',
#  'tyler',
#  'pump',
#  'talkin',
#  'could',
#  'campu',
#  'gull',
#  'bahrain',
#  'dannyraynard',
#  'buyout',
#  'gail',
#  'cowork',
#  'sink',
#  'got',
#  'ran',
#  'x1392',
#  'esn',
#  'gawx',
#  'request',
#  'scotiabank',
#  'welfar',
#  'pp15000266818',
#  'disneyûª',
#  'basic',
#  '20150814',
#  'sackvil',
#  'twain',
#  'kainyusanagi',
#  'bride',
#  'vestment',
#  'inject',
#  'protect',
#  '375',
#  'fr',
#  'firepow',
#  'runnin',
#  'mindset',
#  'ûplot',
#  'steel_lord',
#  'tent',
#  '35',
#  'willian',
#  'manli',
#  'b',
#  'assail',
#  'venezuela',
#  'itrawcwb',
#  '105',
#  'tarp',
#  'indiana',
#  'pin23928835',
#  'chrisdanielshow',
#  'sensei',
#  'sux',
#  'bin',
#  'robertoneill31',
#  'gloucest',
#  'shad',
#  'pradesh',
#  'melani',
#  'appeal',
#  'optimist',
#  'media',
#  'decid',
#  'insurers163million',
#  'flatback',
#  'bit',
#  'trace',
#  'redland',
#  'era',
#  'footbal',
#  'rang',
#  'borderlands2',
#  'may',
#  'wraith',
#  'ensu',
#  'demeanor',
#  'wfp',
#  'yahistor',
#  'mere',
#  'travel',
#  'whopper_jr_760',
#  'rope',
#  'new_hart2010',
#  'reboot',
#  'bhaijaan',
#  'gigant',
#  'gisuserpr',
#  '459',
#  'politicû_',
#  'longfoxy__siren',
#  'tonycottee1986',
#  'freeallfour',
#  'fuck',
#  'reaû_',
#  'arena',
#  'uptown',
#  'lifelong',
#  'purs',
#  'michael5so',
#  'hubri',
#  'jetengin',
#  'katrina',
#  'relay',
#  'constitut',
#  'usar15',
#  'pragnik',
#  'healthandsafeti',
#  'sushi',
#  'xii',
#  'papa',
#  'nfl',
#  'sue',
#  'huffpostart',
#  'grandpa',
#  'butter',
#  'werenûªt',
#  'illinoi',
#  'perspect',
#  'patrick',
#  'bounc',
#  'incap',
#  'analysi',
#  'raung',
#  'lumpur',
#  'ika',
#  'hew',
#  '2nd',
#  'nade',
#  'b24fowler',
#  'seeker',
#  'offers2go',
#  'unsens',
#  'icicl',
#  'moham',
#  'anakin',
#  '1965',
#  'aubilenon',
#  'dlc',
#  'fantast',
#  'codycarn',
#  'dream',
#  '194',
#  'ceo',
#  'ontejc',
#  '0800',
#  'smooth',
#  'bid',
#  'polar',
#  'wealilknowa',
#  'mcpherson',
#  'heir',
#  'fullblown',
#  'sob',
#  'detroitnew',
#  'ici',
#  'ferrel',
#  'nc',
#  'fatalityuudlk',
#  'reagan',
#  'thrust',
#  'dont',
#  'daysweek',
#  'aladdin',
#  '1008planetû_',
#  'court',
#  'campground',
#  'cork',
#  'stagetwo',
#  'harakiri',
#  'donut',
#  'uncl',
#  'depend',
#  'mikeparractor',
#  'lubric',
#  'tigersjostun',
#  'woundedû',
#  'commenc',
#  'kabwandi_',
#  'store',
#  'detroitpl',
#  'snowstormdespit',
#  'rolandonabeat',
#  'brazil',
#  'darwin',
#  '187',
#  'ophelia',
#  'distract',
#  'theboyofmask',
#  'po_st',
#  'satan',
#  'atm',
#  'mesh',
#  'animallog',
#  'micom',
#  'quick',
#  'klarajoelsson',
#  'mutual',
#  'alvinnelson07',
#  'underway',
#  'åonli',
#  'enhanc',
#  'interestrateriseû',
#  'thebuffshow',
#  'historicchurch',
#  'ordain',
#  'blew',
#  'rat',
#  'juror',
#  'utc20150806',
#  'offload',
#  'mystic',
#  '325',
#  'disappear',
#  'ball',
#  'cite',
#  'northampton',
#  'nennicook',
#  'hao',
#  'workplac',
#  'goshen',
#  'rick',
#  'hearth',
#  'lisatoddsutton',
#  'youngû_',
#  'aan',
#  'wartim',
#  'meter',
#  'caruana',
#  'collab',
#  'yea',
#  'r21',
#  'ûï',
#  'cannot',
#  'rt_america',
#  'chunk',
#  'settl',
#  'girlthatsrio',
#  'lopez',
#  'permiss',
#  'argentina',
#  'ûïhannaphû',
#  'presid',
#  'beatdown',
#  'jacki',
#  '228',
#  'postapocalypticflimflam',
#  'con',
#  'appl',
#  'happili',
#  'peeter',
#  'banthebomb',
#  'haley_whaley',
#  'gordon_r74',
#  'lifetim',
#  'survivorsr',
#  'sleeper',
#  'oliviamiles01',
#  'entertainerû',
#  'lulgzimbestpict',
#  'rosenthalauthor',
#  'apaz',
#  'hapa',
#  '777',
#  'school',
#  'territori',
#  'buddi',
#  'uswarcrim',
#  'amazonûª',
#  'coyot',
#  'heat',
#  'creeper',
#  'edmund',
#  'iot',
#  'injuredû_',
#  'short',
#  'dey',
#  'buffer',
#  'convinc',
#  'ifak',
#  'mukilteo',
#  'peasant',
#  'problem',
#  'fed',
#  'discoveri',
#  'pioneerpress',
#  'amicospizzato',
#  'clubbang',
#  'theyll',
#  'romanticsuspens',
#  'sul',
#  'coyi',
#  'pass',
#  'jusreign',
#  'implic',
#  'pit',
#  'dobut',
#  'irelandw',
#  '670thescor',
#  'midfield',
#  'mount',
#  'flag',
#  'cyclonesama',
#  'size',
#  'ptbo',
#  'julian_lag',
#  '1581017',
#  'casualti',
#  'gloriavelez',
#  'despit',
#  'journal',
#  'strickskin',
#  'burford',
#  'sanford',
#  'juici',
#  'vale',
#  'valleywx',
#  'jlabuz',
#  'raidersreport',
#  'welovela',
#  'sir',
#  'freemurphi',
#  'mateo',
#  'cari',
#  'roh3',
#  'oun',
#  'mysteri',
#  'menûª',
#  'architectur',
#  'summerhalleri',
#  'cdc',
#  '43',
#  'sopam',
#  'spread',
#  'hiroshima',
#  'justicepeac',
#  'karachi',
#  'vist',
#  'encor',
#  'targ',
#  'mayonnais',
#  'm8',
#  'pave',
#  'nate',
#  'brbr',
#  'besaf',
#  'passeng',
#  'atljw',
#  'hailstorm',
#  'standardis',
#  'icelandreview',
#  'woodchuck',
#  'forefath',
#  'coquitlam',
#  'bungi',
#  'instaquot',
#  'miracl',
#  'hadnt',
#  'thirtyf',
#  'okanagan',
#  'airplaneåê29072015',
#  'shot',
#  'plane',
#  'region',
#  'atlarnxx',
#  'firebal',
#  'natwest',
#  'glass',
#  'hgf52611',
#  'guild',
#  'exum',
#  'glassanim',
#  'motley',
#  'calfir',
#  'undermin',
#  'rude',
#  'militarydotcom',
#  'patron',
#  'rais',
#  'emily4everev',
#  'elitesportsni',
#  'citi',
#  'peopl',
#  'revers',
#  'webinar',
#  'field',
#  'pirat',
#  '12v',
#  'winger',
#  'nolesfan05',
#  'hlg',
#  'harveymain',
#  'ckec',
#  'forreal',
#  'laevantin',
#  'southdown',
#  '79yearold',
#  'preview',
#  'mthe',
#  'haji_hunter762',
#  'outcri',
#  'moscow',
#  'shouldnt',
#  'whenev',
#  'typewrit',
#  'core',
#  'thurlow',
#  'cell',
#  'isisû_',
#  'litterûª',
#  'balconi',
#  'bigåêconsequ',
#  'trash',
#  'pastur',
#  'revel',
#  'mf',
#  '1979',
#  'ministersay',
#  'clever',
#  'm27329',
#  'slayer',
#  'triniti',
#  'shaper',
#  'juneau',
#  'wouldnûªt',
#  'final',
#  'rjkrraj',
#  'ohlordi',
#  '7aal',
#  'midtown',
#  'truelov',
#  '536',
#  'know',
#  'shekhargupta',
#  'sunflow',
#  'zimmer',
#  'mortar',
#  'dailyko',
#  'benitez',
#  'thinner',
#  'tiffanyfrizzel',
#  'instal',
#  'washington',
#  'askh3cz',
#  'shestooyoung',
#  'youll',
#  'council',
#  'finalis',
#  'mirkwood',
#  'alexhammerston',
#  'boweû_',
#  'provoc',
#  'valu',
#  'beckarnley',
#  'continuinglet',
#  'yoeni',
#  'chillin',
#  'manzanita',
#  'reportedli',
#  'fever',
#  'teamhendrick',
#  'snuff',
#  'jesu',
#  'mgr',
#  'guillermo',
#  'nvr',
#  'delmont',
#  'fundwhen',
#  'citru',
#  'abbyairshow',
#  '15000270653',
#  'islamaphob',
#  'shade',
#  'vixstuart',
#  'forgiven',
#  'news3lv',
#  'hollyorange8',
#  'ems1',
#  'patrol',
#  'vuzuhustl',
#  'fdbdp',
#  'pusssssssssi',
#  'ts',
#  'longll',
#  'infectionsdeath',
#  'suicidebycop',
#  'flavor',
#  'taxiway',
#  'blizzard',
#  'wod',
#  'listenl',
#  'technica',
#  'meaganerd',
#  'churchil',
#  'forthright',
#  'pussyxdestroy',
#  'lifethreaten',
#  '21k',
#  'suruì',
#  'cloudi',
#  'dua',
#  'ww',
#  'tnwx',
#  'heyot6',
#  'herei',
#  'tallest',
#  'varieti',
#  'ohgod',
#  'yard',
#  'scarier',
#  'passion',
#  'farewel',
#  '56',
#  'loudest',
#  'sef',
#  'jess',
#  'bkn025',
#  'barbar',
#  'zss',
#  'airwav',
#  'osborn',
#  'although',
#  'davidû_',
#  'tanstaafl23',
#  'birth',
#  'pete_r_knox',
#  'rhee1975',
#  '182245',
#  'reaction',
#  'bed',
#  'remodel',
#  'quran',
#  'ûïparti',
#  'libya',
#  'autom',
#  'mtgrotto',
#  'veldfest',
#  'dl',
#  'kfc',
#  'tipster',
#  'wnd',
#  'ahead',
#  'found',
#  'specialne',
#  'gt50',
#  'awesom',
#  'loot',
#  'moist',
#  '010401',
#  'stuart',
#  'lmfaoooo',
#  'increment',
#  'madonnamk',
#  'pawsox',
#  'fuckin',
#  'leadership',
#  'kosher',
#  'capit',
#  'argent',
#  'mobil',
#  'satin',
#  'swam',
#  'intertwin',
#  'outbound',
#  'sapphirescallop',
#  'basement',
#  'pyrbliss',
#  'au',
#  '47km',
#  'thu',
#  'mclaughlin',
#  'ruin',
#  'dailyliber',
#  'experienc',
#  'summerslam',
#  'asset',
#  'as10004',
#  'lolim',
#  'pouch',
#  'iaff36',
#  'farrakhan',
#  'acebab',
#  'influenc',
#  'throat',
#  'kno',
#  'sabotagei',
#  'brother',
#  'built',
#  'yumiko',
#  'trfc',
#  'warnedû',
#  'parent',
#  'busey',
#  'low',
#  'robertcalifornia',
#  'forsyth',
#  'safyuan',
#  'focus',
#  'fari',
#  'intern',
#  'specci',
#  'statesû_',
#  'bark',
#  'bland',
#  'withstand',
#  'mcfadden',
#  'lobo_paranoico',
#  'bust',
#  'tootru',
#  'witch',
#  'phillip',
#  'droughtcheck',
#  'blackwhit',
#  'aisl',
#  'destini',
#  'resort',
#  'lao',
#  'robertbenglund',
#  'breeder',
#  'wannab',
#  'tastemycupcake',
#  'dial',
#  'bachmann',
#  'men',
#  'courtney',
#  'hyider_ghost2',
#  'coverup',
#  'gulfport',
#  'appreciativeinquiri',
#  'habit',
#  'elliott',
#  'instantli',
#  'temporarili',
#  'eeasterling_2',
#  'fa',
#  'gentli',
#  'bruv',
#  'pan',
#  'complianc',
#  'barack',
#  'seismic',
#  'legna989',
#  'nalathekoala',
#  'adultblackmal',
#  'ghul',
#  'christopherszen',
#  'flavorchargedtea',
#  'americanlegion',
#  'beyhiv',
#  'madmakni',
#  'livemint',
#  'mmmm',
#  'sought',
#  'vote',
#  'submerg',
#  'gohanûª',
#  'bonnieg434',
#  'dannyoneil',
#  'calgari',
#  'lexi',
#  '_animaladvoc',
#  'courtlizcamp',
#  'floorburnt',
#  'closet',
#  'lore',
#  'agw',
#  'dispers',
#  'aggress',
#  'turn',
#  'clair',
#  'faroeisland',
#  'pugwash',
#  'greyston',
#  'edfring',
#  'videogam',
#  'tomclanc',
#  '8515',
#  'teû_',
#  'ûïthehighfess',
#  'spookyfob',
#  'instant',
#  'thehammers_',
#  'ime',
#  'dojo',
#  'smelltast',
#  'toxicsavior_',
#  'himalaya',
#  'tuna',
#  'khan',
#  'teamatowinn',
#  'bloodymonday',
#  'khuzdar',
#  'jean',
#  'hhbu',
#  '2005',
#  'factor',
#  'yahootv',
#  'm6x100',
#  'heysundown',
#  'aogashima',
#  'beer',
#  'www',
#  'queen',
#  'lawx',
#  '1699',
#  'wrongdejavu',
#  'petebest',
#  'expectû_',
#  'bayelsa',
#  'froze',
#  'increasingli',
#  'rundown',
#  'peac',
#  'transgend',
#  'bean',
#  'otratmetlif',
#  'mihirssharma',
#  'chose',
#  'jrowah',
#  'kylewappl',
#  'fri',
#  'rushhour',
#  'theramin',
#  'nexu',
#  'assnchat',
#  'aeg',
#  'bradi',
#  'oomf',
#  'shen',
#  'eyewit',
#  'worsen',
#  'ûill',
#  'amread',
#  'nucleard',
#  '1388',
#  'sharp',
#  'appreci',
#  'goonda',
#  'bubblycuteon',
#  'bye',
#  'obvious',
#  'disrespect',
#  'stevenontwatt',
#  'gtxrwm',
#  'flew',
#  'dzafic_hari',
#  'hana',
#  'paulhollywood',
#  'musik',
#  'grow',
#  'maca',
#  'greec',
#  'destinythegam',
#  '001116',
#  'superior',
#  'deliciousvomit',
#  'centr',
#  'erect',
#  'wfaaweath',
#  'wave',
#  'linden',
#  'dserialpcilp',
#  'pestl',
#  'colinhoffman29',
#  'reggaeboyz',
#  'narciss',
#  'sequenc',
#  'karijob',
#  'unconfirm',
#  'presinkhol',
#  'quak',
#  '89x',
#  '75',
#  '02',
#  'migrantsû_',
#  'restrospect',
#  'simmon',
#  'crushmtvhottest',
#  '0936',
#  'hoop',
#  'chili',
#  'monday',
#  'c',
#  'kelbytomlinson',
#  'shakjn',
#  'overwork',
#  'reput',
#  'wm',
#  'rossbarton',
#  'naval',
#  'holodomor',
#  'fleek',
#  'thetxi',
#  'informantûª',
#  'arm',
#  '17jul2015',
#  'samesex',
#  'nlwx',
#  'deactiv',
#  '22',
#  'gif',
#  'restiv',
#  'amo',
#  'poor',
#  'credit',
#  'gosh',
#  'plannedparenthood',
#  'devia',
#  'jwalkerlyl',
#  'josephjett',
#  'cityofcalgari',
#  'dialys',
#  'worldwid',
#  'tb',
#  'ìñ',
#  'elielcruz',
#  'breaking144',
#  'gpv',
#  'rural',
#  'heartless',
#  'anthrax',
#  'act',
#  'ipad',
#  ...]

# %%
len(dictionary)
# Out:
# 14969

# %% [markdown]
# 6) Label Encode words in dictionary.

# %%
word_set = {}
for i, w in enumerate(dictionary):
    word_set[w] = i

# %%
word_set
# Out:
# {'goblu': 0,
#  'high': 1,
#  'pope': 2,
#  'mug': 3,
#  'morevoic': 4,
#  'whirlwind': 5,
#  'parter': 6,
#  'small': 7,
#  'deadgirltalk': 8,
#  'woe': 9,
#  'kasiakosek': 10,
#  'poconorecord': 11,
#  'nypd': 12,
#  'mogacola': 13,
#  'feelslikefob': 14,
#  'contrast': 15,
#  'nathan': 16,
#  'ju': 17,
#  'unsaf': 18,
#  'first': 19,
#  'baseman': 20,
#  'rabbit': 21,
#  'everybodi': 22,
#  'ward': 23,
#  'michaelwestbiz': 24,
#  'counselor': 25,
#  'honeybunzgem': 26,
#  'pic': 27,
#  'p45perez': 28,
#  'sfgiant': 29,
#  'b5': 30,
#  'stonewal': 31,
#  'slimebeast': 32,
#  'ådaniel': 33,
#  'afghetcleft': 34,
#  'ironmanå': 35,
#  'extermin': 36,
#  'manag': 37,
#  'motogp': 38,
#  'robsimss': 39,
#  'quiz': 40,
#  'jeannamibian': 41,
#  'gold': 42,
#  'grudg': 43,
#  'inj': 44,
#  '900': 45,
#  'loughe': 46,
#  'strait': 47,
#  'segment': 48,
#  'topic': 49,
#  'ir': 50,
#  'pixelcanuck': 51,
#  'steamship': 52,
#  'djicemoon': 53,
#  'demolish': 54,
#  'hairbut': 55,
#  'juic': 56,
#  'end': 57,
#  'badirand': 58,
#  'peal': 59,
#  'blais': 60,
#  'akilah': 61,
#  'behindashield': 62,
#  'sl': 63,
#  'reid': 64,
#  'nitishkumar': 65,
#  'blitz': 66,
#  'bloopandablast': 67,
#  'kcrw': 68,
#  'windmi': 69,
#  'imsort': 70,
#  'basket': 71,
#  'sarah': 72,
#  'biggangvh1': 73,
#  'retir': 74,
#  'rise': 75,
#  '1rockstar62': 76,
#  'gray': 77,
#  'downgrad': 78,
#  'udhampuragain': 79,
#  'litani': 80,
#  'societi': 81,
#  'push2left': 82,
#  'philippi': 83,
#  'va': 84,
#  'hypo': 85,
#  'fahlowcw': 86,
#  'û_': 87,
#  'rescuer': 88,
#  '7475': 89,
#  'mississippi': 90,
#  'aintsheperti': 91,
#  'wn': 92,
#  'slaughter': 93,
#  'aussi': 94,
#  'hunterston': 95,
#  'exhibit': 96,
#  'resoluteshield': 97,
#  'olliebailey11': 98,
#  '7': 99,
#  'damidnight': 100,
#  'outnumb': 101,
#  'fjord': 102,
#  'idp': 103,
#  'hanna_brooksi': 104,
#  'offer': 105,
#  'blowjob': 106,
#  '60': 107,
#  'social': 108,
#  '23km': 109,
#  'presum': 110,
#  'ethic': 111,
#  'exhaust': 112,
#  'testicl': 113,
#  'saku_uchiha_': 114,
#  'milita': 115,
#  'vampir': 116,
#  'certainli': 117,
#  'mind_mischief': 118,
#  'scheme': 119,
#  'punkblunt': 120,
#  '9058778591': 121,
#  'disasterû': 122,
#  'concentr': 123,
#  'bomairing': 124,
#  'zomatoau': 125,
#  'bonhomme37': 126,
#  'lolol': 127,
#  'icemoon': 128,
#  'compet': 129,
#  'cheer': 130,
#  'function': 131,
#  'akito': 132,
#  'terrain': 133,
#  'modibo': 134,
#  'steel': 135,
#  'sanûªa': 136,
#  'thetimepast': 137,
#  'hair': 138,
#  'browseråêhijack': 139,
#  'ûgood': 140,
#  'waterû_': 141,
#  'chiasson': 142,
#  'special': 143,
#  'pay': 144,
#  'wce': 145,
#  'jj': 146,
#  'mediterranean': 147,
#  'boundari': 148,
#  'reddish': 149,
#  'interrog': 150,
#  'doppler': 151,
#  'cat': 152,
#  'littledeath': 153,
#  'workd': 154,
#  '_onlyftf': 155,
#  'vela': 156,
#  'pagasa': 157,
#  'knive': 158,
#  'ggindependencmessag': 159,
#  'dravet': 160,
#  'pd': 161,
#  'sfgate': 162,
#  'disgust': 163,
#  'fundrais': 164,
#  'legisl': 165,
#  'constel': 166,
#  '1030pm': 167,
#  'oral': 168,
#  'print': 169,
#  'friend59': 170,
#  'spin': 171,
#  'faulti': 172,
#  'refugio': 173,
#  'mauryn143': 174,
#  'storen': 175,
#  'shell': 176,
#  'poison': 177,
#  'tyler': 178,
#  'pump': 179,
#  'talkin': 180,
#  'could': 181,
#  'campu': 182,
#  'gull': 183,
#  'bahrain': 184,
#  'dannyraynard': 185,
#  'buyout': 186,
#  'gail': 187,
#  'cowork': 188,
#  'sink': 189,
#  'got': 190,
#  'ran': 191,
#  'x1392': 192,
#  'esn': 193,
#  'gawx': 194,
#  'request': 195,
#  'scotiabank': 196,
#  'welfar': 197,
#  'pp15000266818': 198,
#  'disneyûª': 199,
#  'basic': 200,
#  '20150814': 201,
#  'sackvil': 202,
#  'twain': 203,
#  'kainyusanagi': 204,
#  'bride': 205,
#  'vestment': 206,
#  'inject': 207,
#  'protect': 208,
#  '375': 209,
#  'fr': 210,
#  'firepow': 211,
#  'runnin': 212,
#  'mindset': 213,
#  'ûplot': 214,
#  'steel_lord': 215,
#  'tent': 216,
#  '35': 217,
#  'willian': 218,
#  'manli': 219,
#  'b': 220,
#  'assail': 221,
#  'venezuela': 222,
#  'itrawcwb': 223,
#  '105': 224,
#  'tarp': 225,
#  'indiana': 226,
#  'pin23928835': 227,
#  'chrisdanielshow': 228,
#  'sensei': 229,
#  'sux': 230,
#  'bin': 231,
#  'robertoneill31': 232,
#  'gloucest': 233,
#  'shad': 234,
#  'pradesh': 235,
#  'melani': 236,
#  'appeal': 237,
#  'optimist': 238,
#  'media': 239,
#  'decid': 240,
#  'insurers163million': 241,
#  'flatback': 242,
#  'bit': 243,
#  'trace': 244,
#  'redland': 245,
#  'era': 246,
#  'footbal': 247,
#  'rang': 248,
#  'borderlands2': 249,
#  'may': 250,
#  'wraith': 251,
#  'ensu': 252,
#  'demeanor': 253,
#  'wfp': 254,
#  'yahistor': 255,
#  'mere': 256,
#  'travel': 257,
#  'whopper_jr_760': 258,
#  'rope': 259,
#  'new_hart2010': 260,
#  'reboot': 261,
#  'bhaijaan': 262,
#  'gigant': 263,
#  'gisuserpr': 264,
#  '459': 265,
#  'politicû_': 266,
#  'longfoxy__siren': 267,
#  'tonycottee1986': 268,
#  'freeallfour': 269,
#  'fuck': 270,
#  'reaû_': 271,
#  'arena': 272,
#  'uptown': 273,
#  'lifelong': 274,
#  'purs': 275,
#  'michael5so': 276,
#  'hubri': 277,
#  'jetengin': 278,
#  'katrina': 279,
#  'relay': 280,
#  'constitut': 281,
#  'usar15': 282,
#  'pragnik': 283,
#  'healthandsafeti': 284,
#  'sushi': 285,
#  'xii': 286,
#  'papa': 287,
#  'nfl': 288,
#  'sue': 289,
#  'huffpostart': 290,
#  'grandpa': 291,
#  'butter': 292,
#  'werenûªt': 293,
#  'illinoi': 294,
#  'perspect': 295,
#  'patrick': 296,
#  'bounc': 297,
#  'incap': 298,
#  'analysi': 299,
#  'raung': 300,
#  'lumpur': 301,
#  'ika': 302,
#  'hew': 303,
#  '2nd': 304,
#  'nade': 305,
#  'b24fowler': 306,
#  'seeker': 307,
#  'offers2go': 308,
#  'unsens': 309,
#  'icicl': 310,
#  'moham': 311,
#  'anakin': 312,
#  '1965': 313,
#  'aubilenon': 314,
#  'dlc': 315,
#  'fantast': 316,
#  'codycarn': 317,
#  'dream': 318,
#  '194': 319,
#  'ceo': 320,
#  'ontejc': 321,
#  '0800': 322,
#  'smooth': 323,
#  'bid': 324,
#  'polar': 325,
#  'wealilknowa': 326,
#  'mcpherson': 327,
#  'heir': 328,
#  'fullblown': 329,
#  'sob': 330,
#  'detroitnew': 331,
#  'ici': 332,
#  'ferrel': 333,
#  'nc': 334,
#  'fatalityuudlk': 335,
#  'reagan': 336,
#  'thrust': 337,
#  'dont': 338,
#  'daysweek': 339,
#  'aladdin': 340,
#  '1008planetû_': 341,
#  'court': 342,
#  'campground': 343,
#  'cork': 344,
#  'stagetwo': 345,
#  'harakiri': 346,
#  'donut': 347,
#  'uncl': 348,
#  'depend': 349,
#  'mikeparractor': 350,
#  'lubric': 351,
#  'tigersjostun': 352,
#  'woundedû': 353,
#  'commenc': 354,
#  'kabwandi_': 355,
#  'store': 356,
#  'detroitpl': 357,
#  'snowstormdespit': 358,
#  'rolandonabeat': 359,
#  'brazil': 360,
#  'darwin': 361,
#  '187': 362,
#  'ophelia': 363,
#  'distract': 364,
#  'theboyofmask': 365,
#  'po_st': 366,
#  'satan': 367,
#  'atm': 368,
#  'mesh': 369,
#  'animallog': 370,
#  'micom': 371,
#  'quick': 372,
#  'klarajoelsson': 373,
#  'mutual': 374,
#  'alvinnelson07': 375,
#  'underway': 376,
#  'åonli': 377,
#  'enhanc': 378,
#  'interestrateriseû': 379,
#  'thebuffshow': 380,
#  'historicchurch': 381,
#  'ordain': 382,
#  'blew': 383,
#  'rat': 384,
#  'juror': 385,
#  'utc20150806': 386,
#  'offload': 387,
#  'mystic': 388,
#  '325': 389,
#  'disappear': 390,
#  'ball': 391,
#  'cite': 392,
#  'northampton': 393,
#  'nennicook': 394,
#  'hao': 395,
#  'workplac': 396,
#  'goshen': 397,
#  'rick': 398,
#  'hearth': 399,
#  'lisatoddsutton': 400,
#  'youngû_': 401,
#  'aan': 402,
#  'wartim': 403,
#  'meter': 404,
#  'caruana': 405,
#  'collab': 406,
#  'yea': 407,
#  'r21': 408,
#  'ûï': 409,
#  'cannot': 410,
#  'rt_america': 411,
#  'chunk': 412,
#  'settl': 413,
#  'girlthatsrio': 414,
#  'lopez': 415,
#  'permiss': 416,
#  'argentina': 417,
#  'ûïhannaphû': 418,
#  'presid': 419,
#  'beatdown': 420,
#  'jacki': 421,
#  '228': 422,
#  'postapocalypticflimflam': 423,
#  'con': 424,
#  'appl': 425,
#  'happili': 426,
#  'peeter': 427,
#  'banthebomb': 428,
#  'haley_whaley': 429,
#  'gordon_r74': 430,
#  'lifetim': 431,
#  'survivorsr': 432,
#  'sleeper': 433,
#  'oliviamiles01': 434,
#  'entertainerû': 435,
#  'lulgzimbestpict': 436,
#  'rosenthalauthor': 437,
#  'apaz': 438,
#  'hapa': 439,
#  '777': 440,
#  'school': 441,
#  'territori': 442,
#  'buddi': 443,
#  'uswarcrim': 444,
#  'amazonûª': 445,
#  'coyot': 446,
#  'heat': 447,
#  'creeper': 448,
#  'edmund': 449,
#  'iot': 450,
#  'injuredû_': 451,
#  'short': 452,
#  'dey': 453,
#  'buffer': 454,
#  'convinc': 455,
#  'ifak': 456,
#  'mukilteo': 457,
#  'peasant': 458,
#  'problem': 459,
#  'fed': 460,
#  'discoveri': 461,
#  'pioneerpress': 462,
#  'amicospizzato': 463,
#  'clubbang': 464,
#  'theyll': 465,
#  'romanticsuspens': 466,
#  'sul': 467,
#  'coyi': 468,
#  'pass': 469,
#  'jusreign': 470,
#  'implic': 471,
#  'pit': 472,
#  'dobut': 473,
#  'irelandw': 474,
#  '670thescor': 475,
#  'midfield': 476,
#  'mount': 477,
#  'flag': 478,
#  'cyclonesama': 479,
#  'size': 480,
#  'ptbo': 481,
#  'julian_lag': 482,
#  '1581017': 483,
#  'casualti': 484,
#  'gloriavelez': 485,
#  'despit': 486,
#  'journal': 487,
#  'strickskin': 488,
#  'burford': 489,
#  'sanford': 490,
#  'juici': 491,
#  'vale': 492,
#  'valleywx': 493,
#  'jlabuz': 494,
#  'raidersreport': 495,
#  'welovela': 496,
#  'sir': 497,
#  'freemurphi': 498,
#  'mateo': 499,
#  'cari': 500,
#  'roh3': 501,
#  'oun': 502,
#  'mysteri': 503,
#  'menûª': 504,
#  'architectur': 505,
#  'summerhalleri': 506,
#  'cdc': 507,
#  '43': 508,
#  'sopam': 509,
#  'spread': 510,
#  'hiroshima': 511,
#  'justicepeac': 512,
#  'karachi': 513,
#  'vist': 514,
#  'encor': 515,
#  'targ': 516,
#  'mayonnais': 517,
#  'm8': 518,
#  'pave': 519,
#  'nate': 520,
#  'brbr': 521,
#  'besaf': 522,
#  'passeng': 523,
#  'atljw': 524,
#  'hailstorm': 525,
#  'standardis': 526,
#  'icelandreview': 527,
#  'woodchuck': 528,
#  'forefath': 529,
#  'coquitlam': 530,
#  'bungi': 531,
#  'instaquot': 532,
#  'miracl': 533,
#  'hadnt': 534,
#  'thirtyf': 535,
#  'okanagan': 536,
#  'airplaneåê29072015': 537,
#  'shot': 538,
#  'plane': 539,
#  'region': 540,
#  'atlarnxx': 541,
#  'firebal': 542,
#  'natwest': 543,
#  'glass': 544,
#  'hgf52611': 545,
#  'guild': 546,
#  'exum': 547,
#  'glassanim': 548,
#  'motley': 549,
#  'calfir': 550,
#  'undermin': 551,
#  'rude': 552,
#  'militarydotcom': 553,
#  'patron': 554,
#  'rais': 555,
#  'emily4everev': 556,
#  'elitesportsni': 557,
#  'citi': 558,
#  'peopl': 559,
#  'revers': 560,
#  'webinar': 561,
#  'field': 562,
#  'pirat': 563,
#  '12v': 564,
#  'winger': 565,
#  'nolesfan05': 566,
#  'hlg': 567,
#  'harveymain': 568,
#  'ckec': 569,
#  'forreal': 570,
#  'laevantin': 571,
#  'southdown': 572,
#  '79yearold': 573,
#  'preview': 574,
#  'mthe': 575,
#  'haji_hunter762': 576,
#  'outcri': 577,
#  'moscow': 578,
#  'shouldnt': 579,
#  'whenev': 580,
#  'typewrit': 581,
#  'core': 582,
#  'thurlow': 583,
#  'cell': 584,
#  'isisû_': 585,
#  'litterûª': 586,
#  'balconi': 587,
#  'bigåêconsequ': 588,
#  'trash': 589,
#  'pastur': 590,
#  'revel': 591,
#  'mf': 592,
#  '1979': 593,
#  'ministersay': 594,
#  'clever': 595,
#  'm27329': 596,
#  'slayer': 597,
#  'triniti': 598,
#  'shaper': 599,
#  'juneau': 600,
#  'wouldnûªt': 601,
#  'final': 602,
#  'rjkrraj': 603,
#  'ohlordi': 604,
#  '7aal': 605,
#  'midtown': 606,
#  'truelov': 607,
#  '536': 608,
#  'know': 609,
#  'shekhargupta': 610,
#  'sunflow': 611,
#  'zimmer': 612,
#  'mortar': 613,
#  'dailyko': 614,
#  'benitez': 615,
#  'thinner': 616,
#  'tiffanyfrizzel': 617,
#  'instal': 618,
#  'washington': 619,
#  'askh3cz': 620,
#  'shestooyoung': 621,
#  'youll': 622,
#  'council': 623,
#  'finalis': 624,
#  'mirkwood': 625,
#  'alexhammerston': 626,
#  'boweû_': 627,
#  'provoc': 628,
#  'valu': 629,
#  'beckarnley': 630,
#  'continuinglet': 631,
#  'yoeni': 632,
#  'chillin': 633,
#  'manzanita': 634,
#  'reportedli': 635,
#  'fever': 636,
#  'teamhendrick': 637,
#  'snuff': 638,
#  'jesu': 639,
#  'mgr': 640,
#  'guillermo': 641,
#  'nvr': 642,
#  'delmont': 643,
#  'fundwhen': 644,
#  'citru': 645,
#  'abbyairshow': 646,
#  '15000270653': 647,
#  'islamaphob': 648,
#  'shade': 649,
#  'vixstuart': 650,
#  'forgiven': 651,
#  'news3lv': 652,
#  'hollyorange8': 653,
#  'ems1': 654,
#  'patrol': 655,
#  'vuzuhustl': 656,
#  'fdbdp': 657,
#  'pusssssssssi': 658,
#  'ts': 659,
#  'longll': 660,
#  'infectionsdeath': 661,
#  'suicidebycop': 662,
#  'flavor': 663,
#  'taxiway': 664,
#  'blizzard': 665,
#  'wod': 666,
#  'listenl': 667,
#  'technica': 668,
#  'meaganerd': 669,
#  'churchil': 670,
#  'forthright': 671,
#  'pussyxdestroy': 672,
#  'lifethreaten': 673,
#  '21k': 674,
#  'suruì': 675,
#  'cloudi': 676,
#  'dua': 677,
#  'ww': 678,
#  'tnwx': 679,
#  'heyot6': 680,
#  'herei': 681,
#  'tallest': 682,
#  'varieti': 683,
#  'ohgod': 684,
#  'yard': 685,
#  'scarier': 686,
#  'passion': 687,
#  'farewel': 688,
#  '56': 689,
#  'loudest': 690,
#  'sef': 691,
#  'jess': 692,
#  'bkn025': 693,
#  'barbar': 694,
#  'zss': 695,
#  'airwav': 696,
#  'osborn': 697,
#  'although': 698,
#  'davidû_': 699,
#  'tanstaafl23': 700,
#  'birth': 701,
#  'pete_r_knox': 702,
#  'rhee1975': 703,
#  '182245': 704,
#  'reaction': 705,
#  'bed': 706,
#  'remodel': 707,
#  'quran': 708,
#  'ûïparti': 709,
#  'libya': 710,
#  'autom': 711,
#  'mtgrotto': 712,
#  'veldfest': 713,
#  'dl': 714,
#  'kfc': 715,
#  'tipster': 716,
#  'wnd': 717,
#  'ahead': 718,
#  'found': 719,
#  'specialne': 720,
#  'gt50': 721,
#  'awesom': 722,
#  'loot': 723,
#  'moist': 724,
#  '010401': 725,
#  'stuart': 726,
#  'lmfaoooo': 727,
#  'increment': 728,
#  'madonnamk': 729,
#  'pawsox': 730,
#  'fuckin': 731,
#  'leadership': 732,
#  'kosher': 733,
#  'capit': 734,
#  'argent': 735,
#  'mobil': 736,
#  'satin': 737,
#  'swam': 738,
#  'intertwin': 739,
#  'outbound': 740,
#  'sapphirescallop': 741,
#  'basement': 742,
#  'pyrbliss': 743,
#  'au': 744,
#  '47km': 745,
#  'thu': 746,
#  'mclaughlin': 747,
#  'ruin': 748,
#  'dailyliber': 749,
#  'experienc': 750,
#  'summerslam': 751,
#  'asset': 752,
#  'as10004': 753,
#  'lolim': 754,
#  'pouch': 755,
#  'iaff36': 756,
#  'farrakhan': 757,
#  'acebab': 758,
#  'influenc': 759,
#  'throat': 760,
#  'kno': 761,
#  'sabotagei': 762,
#  'brother': 763,
#  'built': 764,
#  'yumiko': 765,
#  'trfc': 766,
#  'warnedû': 767,
#  'parent': 768,
#  'busey': 769,
#  'low': 770,
#  'robertcalifornia': 771,
#  'forsyth': 772,
#  'safyuan': 773,
#  'focus': 774,
#  'fari': 775,
#  'intern': 776,
#  'specci': 777,
#  'statesû_': 778,
#  'bark': 779,
#  'bland': 780,
#  'withstand': 781,
#  'mcfadden': 782,
#  'lobo_paranoico': 783,
#  'bust': 784,
#  'tootru': 785,
#  'witch': 786,
#  'phillip': 787,
#  'droughtcheck': 788,
#  'blackwhit': 789,
#  'aisl': 790,
#  'destini': 791,
#  'resort': 792,
#  'lao': 793,
#  'robertbenglund': 794,
#  'breeder': 795,
#  'wannab': 796,
#  'tastemycupcake': 797,
#  'dial': 798,
#  'bachmann': 799,
#  'men': 800,
#  'courtney': 801,
#  'hyider_ghost2': 802,
#  'coverup': 803,
#  'gulfport': 804,
#  'appreciativeinquiri': 805,
#  'habit': 806,
#  'elliott': 807,
#  'instantli': 808,
#  'temporarili': 809,
#  'eeasterling_2': 810,
#  'fa': 811,
#  'gentli': 812,
#  'bruv': 813,
#  'pan': 814,
#  'complianc': 815,
#  'barack': 816,
#  'seismic': 817,
#  'legna989': 818,
#  'nalathekoala': 819,
#  'adultblackmal': 820,
#  'ghul': 821,
#  'christopherszen': 822,
#  'flavorchargedtea': 823,
#  'americanlegion': 824,
#  'beyhiv': 825,
#  'madmakni': 826,
#  'livemint': 827,
#  'mmmm': 828,
#  'sought': 829,
#  'vote': 830,
#  'submerg': 831,
#  'gohanûª': 832,
#  'bonnieg434': 833,
#  'dannyoneil': 834,
#  'calgari': 835,
#  'lexi': 836,
#  '_animaladvoc': 837,
#  'courtlizcamp': 838,
#  'floorburnt': 839,
#  'closet': 840,
#  'lore': 841,
#  'agw': 842,
#  'dispers': 843,
#  'aggress': 844,
#  'turn': 845,
#  'clair': 846,
#  'faroeisland': 847,
#  'pugwash': 848,
#  'greyston': 849,
#  'edfring': 850,
#  'videogam': 851,
#  'tomclanc': 852,
#  '8515': 853,
#  'teû_': 854,
#  'ûïthehighfess': 855,
#  'spookyfob': 856,
#  'instant': 857,
#  'thehammers_': 858,
#  'ime': 859,
#  'dojo': 860,
#  'smelltast': 861,
#  'toxicsavior_': 862,
#  'himalaya': 863,
#  'tuna': 864,
#  'khan': 865,
#  'teamatowinn': 866,
#  'bloodymonday': 867,
#  'khuzdar': 868,
#  'jean': 869,
#  'hhbu': 870,
#  '2005': 871,
#  'factor': 872,
#  'yahootv': 873,
#  'm6x100': 874,
#  'heysundown': 875,
#  'aogashima': 876,
#  'beer': 877,
#  'www': 878,
#  'queen': 879,
#  'lawx': 880,
#  '1699': 881,
#  'wrongdejavu': 882,
#  'petebest': 883,
#  'expectû_': 884,
#  'bayelsa': 885,
#  'froze': 886,
#  'increasingli': 887,
#  'rundown': 888,
#  'peac': 889,
#  'transgend': 890,
#  'bean': 891,
#  'otratmetlif': 892,
#  'mihirssharma': 893,
#  'chose': 894,
#  'jrowah': 895,
#  'kylewappl': 896,
#  'fri': 897,
#  'rushhour': 898,
#  'theramin': 899,
#  'nexu': 900,
#  'assnchat': 901,
#  'aeg': 902,
#  'bradi': 903,
#  'oomf': 904,
#  'shen': 905,
#  'eyewit': 906,
#  'worsen': 907,
#  'ûill': 908,
#  'amread': 909,
#  'nucleard': 910,
#  '1388': 911,
#  'sharp': 912,
#  'appreci': 913,
#  'goonda': 914,
#  'bubblycuteon': 915,
#  'bye': 916,
#  'obvious': 917,
#  'disrespect': 918,
#  'stevenontwatt': 919,
#  'gtxrwm': 920,
#  'flew': 921,
#  'dzafic_hari': 922,
#  'hana': 923,
#  'paulhollywood': 924,
#  'musik': 925,
#  'grow': 926,
#  'maca': 927,
#  'greec': 928,
#  'destinythegam': 929,
#  '001116': 930,
#  'superior': 931,
#  'deliciousvomit': 932,
#  'centr': 933,
#  'erect': 934,
#  'wfaaweath': 935,
#  'wave': 936,
#  'linden': 937,
#  'dserialpcilp': 938,
#  'pestl': 939,
#  'colinhoffman29': 940,
#  'reggaeboyz': 941,
#  'narciss': 942,
#  'sequenc': 943,
#  'karijob': 944,
#  'unconfirm': 945,
#  'presinkhol': 946,
#  'quak': 947,
#  '89x': 948,
#  '75': 949,
#  '02': 950,
#  'migrantsû_': 951,
#  'restrospect': 952,
#  'simmon': 953,
#  'crushmtvhottest': 954,
#  '0936': 955,
#  'hoop': 956,
#  'chili': 957,
#  'monday': 958,
#  'c': 959,
#  'kelbytomlinson': 960,
#  'shakjn': 961,
#  'overwork': 962,
#  'reput': 963,
#  'wm': 964,
#  'rossbarton': 965,
#  'naval': 966,
#  'holodomor': 967,
#  'fleek': 968,
#  'thetxi': 969,
#  'informantûª': 970,
#  'arm': 971,
#  '17jul2015': 972,
#  'samesex': 973,
#  'nlwx': 974,
#  'deactiv': 975,
#  '22': 976,
#  'gif': 977,
#  'restiv': 978,
#  'amo': 979,
#  'poor': 980,
#  'credit': 981,
#  'gosh': 982,
#  'plannedparenthood': 983,
#  'devia': 984,
#  'jwalkerlyl': 985,
#  'josephjett': 986,
#  'cityofcalgari': 987,
#  'dialys': 988,
#  'worldwid': 989,
#  'tb': 990,
#  'ìñ': 991,
#  'elielcruz': 992,
#  'breaking144': 993,
#  'gpv': 994,
#  'rural': 995,
#  'heartless': 996,
#  'anthrax': 997,
#  'act': 998,
#  'ipad': 999,
#  ...}
